# %% [markdown]
# <a href="https://colab.research.google.com/github/kylewinfree/inf502-fall2025/blob/main/rest/REST_APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using REST APIs as data sources
#
# * Data is everywhere and it is generated constantly
# * The number of data sources is amazingly huge
# * Datasets are huge and can be used in many ways
#
# * We may do amazing things using data made available by third-party:
#     - https://developer.walmartlabs.com/docs
#     - https://developer.spotify.com/documentation/web-api/
#     - https://earthquake.usgs.gov/fdsnws/event/1/
#
#
# We will have a nice and brief overview about how to consume data from REST APIs, mainly focusing on **JSON**.

# %% [markdown]
# ### What is an API?
#
# **Application Programming Interface** defines the methods for one software program to interact with the other.
#
# In the case of this lecture, we are dealing with a REST API, which sends data over a network: one type of Web service.
#
# When we want to receive data from an Web service, we need to make a `request` to this service. When the server receives this request, it sends a `response`.
#
# ![request.png](request.png)

# %% [markdown]
# ### Requests
#
# Knowing that, we will not have to learn about making requests in Python. Instead, we do it by importing the module requests.

# %%
import requests

# %% [markdown]
# There are different types of requests.
#
# In our case we will use a `GET`, which is used to retrieve data. This is the type of request we use to collect data.
#
# A response from the API contains 2 things (among others):
# * response code
# * response data
#
# To make a request, we use:

# %%
response = requests.get('http://www.nau.edu/')
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# The `request.get(URL)` returns an object Response, which provides, among other things, the response code.

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# The most common codes are:
# * 200: Everything went okay, and the result has been returned (if any).
# * 301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# * 400: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# * 401: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# * 403: The resource you’re trying to access is forbidden: you don’t have the right permissions to see it.
# * 404: The resource you tried to access wasn’t found on the server.
# * 503: The server is not ready to handle the request.
#
# More details about status codes list can be found [here](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status)

# %% [markdown]
# ### What about getting the data?
#
# First, read the documentation! Everytime you use an API, please read the documentation to understand how to use, the structure, etc.
#
# We will use the [Open Notify API](http://api.open-notify.org/), which gives access to data about the international space station.
#
# These APIs usually provide multiple endpoints, which are the ways we can interact with that service.
#
# Let's try a request and see how it goes:

# %%
response = requests.get("http://api.open-notify.org/astros.json")
print(response.status_code)
# Out:
# 200

# %% [markdown]
# Now we can see the data...

# %%
type(response.content)
# Out:
# bytes

# %%
response.text
# Out:
# '{"people": [{"craft": "ISS", "name": "Oleg Kononenko"}, {"craft": "ISS", "name": "Nikolai Chub"}, {"craft": "ISS", "name": "Tracy Caldwell Dyson"}, {"craft": "ISS", "name": "Matthew Dominick"}, {"craft": "ISS", "name": "Michael Barratt"}, {"craft": "ISS", "name": "Jeanette Epps"}, {"craft": "ISS", "name": "Alexander Grebenkin"}, {"craft": "ISS", "name": "Butch Wilmore"}, {"craft": "ISS", "name": "Sunita Williams"}, {"craft": "Tiangong", "name": "Li Guangsu"}, {"craft": "Tiangong", "name": "Li Cong"}, {"craft": "Tiangong", "name": "Ye Guangfu"}], "number": 12, "message": "success"}'

# %%
response.json()
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'},
#   {'craft': 'ISS', 'name': 'Nikolai Chub'},
#   {'craft': 'ISS', 'name': 'Tracy Caldwell Dyson'},
#   {'craft': 'ISS', 'name': 'Matthew Dominick'},
#   {'craft': 'ISS', 'name': 'Michael Barratt'},
#   {'craft': 'ISS', 'name': 'Jeanette Epps'},
#   {'craft': 'ISS', 'name': 'Alexander Grebenkin'},
#   {'craft': 'ISS', 'name': 'Butch Wilmore'},
#   {'craft': 'ISS', 'name': 'Sunita Williams'},
#   {'craft': 'Tiangong', 'name': 'Li Guangsu'},
#   {'craft': 'Tiangong', 'name': 'Li Cong'},
#   {'craft': 'Tiangong', 'name': 'Ye Guangfu'}],
#  'number': 12,
#  'message': 'success'}

# %% [markdown]
# ### Working with JSON
# JSON stands for JavaScript Object Notation. It is a way to encode data structures that ensures that they are easily readable.
#
# JSON output look like Python something with *dictionaries, lists, strings* and *integers*. And it is...
#
# But, how to use it? Well, we used it in the last command.

# %%
import json

# %% [markdown]
# json has two main functions:
#
# * `json.dumps()` — Takes in a Python object and converts (dumps) to a string.
# * `json.loads()` — Takes a JSON string and converts (loads) to a Python object.
#
# The `dumps()` is particularly useful as we can use it to format the json, making it easier to understand the output

# %%
json_response = response.json()
formatted_json = json.dumps(json_response, sort_keys=True, indent=3)

print(formatted_json)
# Out:
# {
#    "message": "success",
#    "number": 12,
#    "people": [
#       {
#          "craft": "ISS",
#          "name": "Oleg Kononenko"
#       },
#       {
#          "craft": "ISS",
#          "name": "Nikolai Chub"
#       },
#       {
#          "craft": "ISS",
#          "name": "Tracy Caldwell Dyson"
#       },
#       {
#          "craft": "ISS",
#          "name": "Matthew Dominick"
#       },
#       {
#          "craft": "ISS",
#          "name": "Michael Barratt"
#       },
#       {
#          "craft": "ISS",
#          "name": "Jeanette Epps"
#       },
#       {
#          "craft": "ISS",
#          "name": "Alexander Grebenkin"
#       },
#       {
#          "craft": "ISS",
#          "name": "Butch Wilmore"
#       },
#       {
#          "craft": "ISS",
#          "name": "Sunita Williams"
#       },
#       {
#          "craft": "Tiangong",
#          "name": "Li Guangsu"
#       },
#       {
#          "craft": "Tiangong",
#          "name": "Li Cong"
#       },
#       {
#          "craft": "Tiangong",
#          "name": "Ye Guangfu"
#       }
#    ]
# }

# %% [markdown]
# ### REST API with Query Parameters
# In some cases, it is possible to pass parameters to filter the output of the API.
#
# The https://earthquake.usgs.gov/fdsnws/event/1/query endpoint tells what are the earthquakes given a set of parameters. For example time, location, etc.
# More information here:
# https://earthquake.usgs.gov/fdsnws/event/1/#parameters
#
# In the example below, we show the earthquakes in January 2022 (`starttime` and `endtime`), with magnitude between 6 and 7 (`minmagnitude` and `maxmagnitude`).

# %%
import requests
import json
from datetime import datetime

response = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2022-01-01&endtime=2022-01-31&maxmagnitude=7&minmagnitude=6")
json_response = response.json()
formatted_json = json.dumps(json_response, sort_keys=False, indent=2)

print(formatted_json)

# %% [markdown]
# # example output

# %%
import requests
import json
from datetime import datetime

response = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-10-01&endtime=2025-10-31&maxmagnitude=8&minmagnitude=5")
json_response = response.json()
formatted_json = json.dumps(json_response, sort_keys=False, indent=2)

print(formatted_json)
# Out:
# {
#   "type": "FeatureCollection",
#   "metadata": {
#     "generated": 1761680801000,
#     "url": "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-10-01&endtime=2025-10-31&maxmagnitude=8&minmagnitude=5",
#     "title": "USGS Earthquakes",
#     "status": 200,
#     "api": "1.14.1",
#     "count": 169
#   },
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.4,
#         "place": "Banda Sea",
#         "time": 1761662418679,
#         "updated": 1761678668510,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjx3",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjx3&format=geojson",
#         "felt": 12,
#         "cdi": 3.2,
#         "mmi": 4.305,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 634,
#         "net": "us",
#         "code": "6000rjx3",
#         "ids": ",us6000rjx3,usauto6000rjx3,pt25301000,at00t4ujf6,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 105,
#         "dmin": 2.143,
#         "rms": 1.03,
#         "gap": 19,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.4 - Banda Sea"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           130.0038,
#           -6.6774,
#           143.626
#         ]
#       },
#       "id": "us6000rjx3"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "83 km WSW of Panguna, Papua New Guinea",
#         "time": 1761642827150,
#         "updated": 1761645758040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjwa",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjwa&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rjwa",
#         "ids": ",us6000rjwa,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 52,
#         "dmin": 3.639,
#         "rms": 0.58,
#         "gap": 61,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - 83 km WSW of Panguna, Papua New Guinea"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           154.8329,
#           -6.6936,
#           10
#         ]
#       },
#       "id": "us6000rjwa"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.7,
#         "place": "95 km ESE of Severo-Kuril\u2019sk, Russia",
#         "time": 1761635186235,
#         "updated": 1761666942040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjvf",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjvf&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 3.951,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 500,
#         "net": "us",
#         "code": "6000rjvf",
#         "ids": ",usauto6000rjvf,us6000rjvf,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 70,
#         "dmin": 2.744,
#         "rms": 0.85,
#         "gap": 112,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.7 - 95 km ESE of Severo-Kuril\u2019sk, Russia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           157.393,
#           50.3753,
#           45.526
#         ]
#       },
#       "id": "us6000rjvf"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "170 km NW of Gorontalo, Indonesia",
#         "time": 1761615078413,
#         "updated": 1761616094040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rju9",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rju9&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000rju9",
#         "ids": ",usauto6000rju9,us6000rju9,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,origin,phase-data,",
#         "nst": 67,
#         "dmin": 1.112,
#         "rms": 1.04,
#         "gap": 65,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.1 - 170 km NW of Gorontalo, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           121.8389,
#           1.4598,
#           9.596
#         ]
#       },
#       "id": "us6000rju9"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "48 km SW of Reuleuet, Indonesia",
#         "time": 1761608113366,
#         "updated": 1761616677040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjtw",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjtw&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000rjtw",
#         "ids": ",us6000rjtw,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 58,
#         "dmin": 1.032,
#         "rms": 0.58,
#         "gap": 45,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.1 - 48 km SW of Reuleuet, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           95.9544,
#           4.933,
#           10
#         ]
#       },
#       "id": "us6000rjtw"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6,
#         "place": "4 km ESE of S\u0131nd\u0131rg\u0131, Turkey",
#         "time": 1761594508858,
#         "updated": 1761679421726,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjsu",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjsu&format=geojson",
#         "felt": 183,
#         "cdi": 7.7,
#         "mmi": 8.118,
#         "alert": "yellow",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 791,
#         "net": "us",
#         "code": "6000rjsu",
#         "ids": ",us6000rjsu,usauto6000rjsu,pt25300003,at00t4t30w,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 125,
#         "dmin": 1.036,
#         "rms": 0.72,
#         "gap": 21,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.0 - 4 km ESE of S\u0131nd\u0131rg\u0131, Turkey"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           28.2279,
#           39.2333,
#           8
#         ]
#       },
#       "id": "us6000rjsu"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.3,
#         "place": "203 km ESE of Kimbe, Papua New Guinea",
#         "time": 1761575373472,
#         "updated": 1761578020040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjri",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjri&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 432,
#         "net": "us",
#         "code": "6000rjri",
#         "ids": ",us6000rjri,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 75,
#         "dmin": 2.12,
#         "rms": 0.66,
#         "gap": 67,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.3 - 203 km ESE of Kimbe, Papua New Guinea"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           151.8136,
#           -6.2958,
#           10
#         ]
#       },
#       "id": "us6000rjri"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.4,
#         "place": "150 km E of Beaus\u00e9jour, Guadeloupe",
#         "time": 1761571611808,
#         "updated": 1761659515561,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjr7",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjr7&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 2.651,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 449,
#         "net": "us",
#         "code": "6000rjr7",
#         "ids": ",usauto6000rjr7,pt25300002,us6000rjr7,",
#         "sources": ",usauto,pt,us,",
#         "types": ",internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 95,
#         "dmin": 1.344,
#         "rms": 0.69,
#         "gap": 37,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.4 - 150 km E of Beaus\u00e9jour, Guadeloupe"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -59.6849,
#           16.5389,
#           10
#         ]
#       },
#       "id": "us6000rjr7"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6,
#         "place": "163 km E of Beaus\u00e9jour, Guadeloupe",
#         "time": 1761569699494,
#         "updated": 1761657870665,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjqj",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjqj&format=geojson",
#         "felt": 8,
#         "cdi": 3.4,
#         "mmi": 3.388,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 557,
#         "net": "us",
#         "code": "6000rjqj",
#         "ids": ",us6000rjqj,",
#         "sources": ",us,",
#         "types": ",dyfi,ground-failure,losspager,origin,phase-data,shakemap,",
#         "nst": 119,
#         "dmin": 1.463,
#         "rms": 0.79,
#         "gap": 28,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 6.0 - 163 km E of Beaus\u00e9jour, Guadeloupe"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -59.5632,
#           16.5587,
#           10
#         ]
#       },
#       "id": "us6000rjqj"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.5,
#         "place": "162 km E of Beaus\u00e9jour, Guadeloupe",
#         "time": 1761568720311,
#         "updated": 1761656781967,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjq8",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjq8&format=geojson",
#         "felt": 119,
#         "cdi": 6.6,
#         "mmi": 3.862,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 1,
#         "sig": 729,
#         "net": "us",
#         "code": "6000rjq8",
#         "ids": ",pt25300000,at00t4sj4k,us6000rjq8,usauto6000rjq8,",
#         "sources": ",pt,at,us,usauto,",
#         "types": ",dyfi,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 139,
#         "dmin": 1.45,
#         "rms": 0.71,
#         "gap": 21,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.5 - 162 km E of Beaus\u00e9jour, Guadeloupe"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -59.5718,
#           16.5295,
#           9
#         ]
#       },
#       "id": "us6000rjq8"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "West Chile Rise",
#         "time": 1761522445201,
#         "updated": 1761527507040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjnc",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjnc&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000rjnc",
#         "ids": ",usauto6000rjnc,us6000rjnc,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,moment-tensor,origin,phase-data,",
#         "nst": 69,
#         "dmin": 14.958,
#         "rms": 0.62,
#         "gap": 102,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.1 - West Chile Rise"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -95.983,
#           -36.9561,
#           10
#         ]
#       },
#       "id": "us6000rjnc"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.2,
#         "place": "59 km NW of Pante Makasar, Timor Leste",
#         "time": 1761498265645,
#         "updated": 1761586332056,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjkv",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjkv&format=geojson",
#         "felt": 10,
#         "cdi": 4.1,
#         "mmi": 5.125,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 595,
#         "net": "us",
#         "code": "6000rjkv",
#         "ids": ",us6000rjkv,usauto6000rjkv,pt25299000,at00t4r0rf,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 99,
#         "dmin": 0.934,
#         "rms": 1.05,
#         "gap": 20,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.2 - 59 km NW of Pante Makasar, Timor Leste"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           123.9517,
#           -8.8689,
#           75
#         ]
#       },
#       "id": "us6000rjkv"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "44 km ESE of Manay, Philippines",
#         "time": 1761438354676,
#         "updated": 1761439318040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjhy",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjhy&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rjhy",
#         "ids": ",us6000rjhy,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 46,
#         "dmin": 1.332,
#         "rms": 1.01,
#         "gap": 105,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - 44 km ESE of Manay, Philippines"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           126.921,
#           7.0758,
#           54.6
#         ]
#       },
#       "id": "us6000rjhy"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6,
#         "place": "197 km SSE of Lata, Solomon Islands",
#         "time": 1761434884780,
#         "updated": 1761522792686,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjhm",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjhm&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 4.486,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 554,
#         "net": "us",
#         "code": "6000rjhm",
#         "ids": ",us6000rjhm,usauto6000rjhm,at00t4pnut,pt25298000,",
#         "sources": ",us,usauto,at,pt,",
#         "types": ",ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 64,
#         "dmin": 6.982,
#         "rms": 0.79,
#         "gap": 54,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.0 - 197 km SSE of Lata, Solomon Islands"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           166.389,
#           -12.4143,
#           54.442
#         ]
#       },
#       "id": "us6000rjhm"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.2,
#         "place": "Off the coast of Aisen, Chile",
#         "time": 1761413375992,
#         "updated": 1761414793040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjgm",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjgm&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 416,
#         "net": "us",
#         "code": "6000rjgm",
#         "ids": ",usauto6000rjgm,us6000rjgm,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,moment-tensor,origin,phase-data,",
#         "nst": 91,
#         "dmin": 3.805,
#         "rms": 0.42,
#         "gap": 107,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.2 - Off the coast of Aisen, Chile"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -77.5018,
#           -45.6518,
#           10
#         ]
#       },
#       "id": "us6000rjgm"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.4,
#         "place": "southeast Indian Ridge",
#         "time": 1761409874166,
#         "updated": 1761500698331,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjgf",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjgf&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 0,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 449,
#         "net": "us",
#         "code": "6000rjgf",
#         "ids": ",usauto6000rjgf,us6000rjgf,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,losspager,origin,phase-data,shakemap,",
#         "nst": 190,
#         "dmin": 18.417,
#         "rms": 0.55,
#         "gap": 27,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.4 - southeast Indian Ridge"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           96.7476,
#           -45.2541,
#           10
#         ]
#       },
#       "id": "us6000rjgf"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.2,
#         "place": "39 km NW of Slavyanka, Russia",
#         "time": 1761392723124,
#         "updated": 1761396988501,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjf6",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjf6&format=geojson",
#         "felt": 1,
#         "cdi": 1,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 416,
#         "net": "us",
#         "code": "6000rjf6",
#         "ids": ",us6000rjf6,usauto6000rjf6,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,origin,phase-data,",
#         "nst": 95,
#         "dmin": 1.33,
#         "rms": 0.51,
#         "gap": 30,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.2 - 39 km NW of Slavyanka, Russia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           131.0017,
#           43.0788,
#           561.686
#         ]
#       },
#       "id": "us6000rjf6"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.3,
#         "place": "86 km S of Severo-Kuril\u2019sk, Russia",
#         "time": 1761390786830,
#         "updated": 1761478741327,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjf1",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjf1&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 4.1,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 432,
#         "net": "us",
#         "code": "6000rjf1",
#         "ids": ",usauto6000rjf1,us6000rjf1,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 82,
#         "dmin": 3.372,
#         "rms": 0.68,
#         "gap": 120,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.3 - 86 km S of Severo-Kuril\u2019sk, Russia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           156.0516,
#           49.9015,
#           47
#         ]
#       },
#       "id": "us6000rjf1"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "51 km SE of Adak, Alaska",
#         "time": 1761387186181,
#         "updated": 1761646997510,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjeu",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjeu&format=geojson",
#         "felt": 1,
#         "cdi": 4.1,
#         "mmi": 3.536,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rjeu",
#         "ids": ",us6000rjeu,ak025dp06jw4,",
#         "sources": ",us,ak,",
#         "types": ",dyfi,oaf,origin,phase-data,shakemap,",
#         "nst": 60,
#         "dmin": 0.566,
#         "rms": 0.79,
#         "gap": 100,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - 51 km SE of Adak, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -176.1245,
#           51.5305,
#           52.588
#         ]
#       },
#       "id": "us6000rjeu"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "57 km NE of Port-Olry, Vanuatu",
#         "time": 1761379947231,
#         "updated": 1761380784040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjeg",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjeg&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000rjeg",
#         "ids": ",us6000rjeg,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 54,
#         "dmin": 6.59,
#         "rms": 0.58,
#         "gap": 60,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.1 - 57 km NE of Port-Olry, Vanuatu"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           167.3955,
#           -14.632,
#           227.522
#         ]
#       },
#       "id": "us6000rjeg"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.3,
#         "place": "Beaufort Sea",
#         "time": 1761374040639,
#         "updated": 1761374944040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rje7",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rje7&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 432,
#         "net": "us",
#         "code": "6000rje7",
#         "ids": ",usauto6000rje7,us6000rje7,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,origin,phase-data,",
#         "nst": 135,
#         "dmin": 3.394,
#         "rms": 0.71,
#         "gap": 28,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.3 - Beaufort Sea"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -131.8847,
#           71.6368,
#           7.747
#         ]
#       },
#       "id": "us6000rje7"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.8,
#         "place": "35 km S of Nemuro, Japan",
#         "time": 1761324010325,
#         "updated": 1761411994784,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rj9f",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rj9f&format=geojson",
#         "felt": 1,
#         "cdi": 2.2,
#         "mmi": 4.865,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 518,
#         "net": "us",
#         "code": "6000rj9f",
#         "ids": ",us6000rj9f,usauto6000rj9f,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 60,
#         "dmin": 2.084,
#         "rms": 1.09,
#         "gap": 113,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.8 - 35 km S of Nemuro, Japan"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           145.6376,
#           43.0043,
#           41.407
#         ]
#       },
#       "id": "us6000rj9f"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "291 km NE of Hicks Bay, New Zealand",
#         "time": 1761294701022,
#         "updated": 1761295821040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rj2t",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rj2t&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rj2t",
#         "ids": ",usauto6000rj2t,us6000rj2t,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,origin,phase-data,",
#         "nst": 43,
#         "dmin": 2.59,
#         "rms": 1.31,
#         "gap": 78,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.0 - 291 km NE of Hicks Bay, New Zealand"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -179.4701,
#           -35.685,
#           10
#         ]
#       },
#       "id": "us6000rj2t"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "78 km WNW of Pante Makasar, Timor Leste",
#         "time": 1761281194891,
#         "updated": 1761500773611,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rj23",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rj23&format=geojson",
#         "felt": 0,
#         "cdi": 1,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000rj23",
#         "ids": ",us6000rj23,",
#         "sources": ",us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": 44,
#         "dmin": 1.026,
#         "rms": 0.75,
#         "gap": 56,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.1 - 78 km WNW of Pante Makasar, Timor Leste"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           123.7551,
#           -8.8562,
#           108.253
#         ]
#       },
#       "id": "us6000rj23"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "South Sandwich Islands region",
#         "time": 1761269210786,
#         "updated": 1761270189040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rj1k",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rj1k&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000rj1k",
#         "ids": ",us6000rj1k,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 44,
#         "dmin": 5.234,
#         "rms": 1.01,
#         "gap": 75,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.1 - South Sandwich Islands region"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -27.8717,
#           -56.0025,
#           106.763
#         ]
#       },
#       "id": "us6000rj1k"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "90 km E of Tomioka, Japan",
#         "time": 1761253767652,
#         "updated": 1761270622534,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rj0d",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rj0d&format=geojson",
#         "felt": 2,
#         "cdi": 2.7,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 401,
#         "net": "us",
#         "code": "6000rj0d",
#         "ids": ",us6000rj0d,",
#         "sources": ",us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": 75,
#         "dmin": 3.19,
#         "rms": 1.1,
#         "gap": 60,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.1 - 90 km E of Tomioka, Japan"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           142.0358,
#           37.4199,
#           40.846
#         ]
#       },
#       "id": "us6000rj0d"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "Falkland Islands region",
#         "time": 1761229512890,
#         "updated": 1761231717040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rivm",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rivm&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rivm",
#         "ids": ",us6000rivm,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 76,
#         "dmin": 2.431,
#         "rms": 0.61,
#         "gap": 74,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - Falkland Islands region"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -58.2948,
#           -54.0977,
#           10
#         ]
#       },
#       "id": "us6000rivm"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.6,
#         "place": "210 km WSW of Tual, Indonesia",
#         "time": 1761219970756,
#         "updated": 1761307772041,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000riuj",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000riuj&format=geojson",
#         "felt": 1,
#         "cdi": 2,
#         "mmi": 3.585,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 483,
#         "net": "us",
#         "code": "6000riuj",
#         "ids": ",us6000riuj,usauto6000riuj,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 81,
#         "dmin": 2.033,
#         "rms": 0.73,
#         "gap": 20,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.6 - 210 km WSW of Tual, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           130.9649,
#           -6.2714,
#           93.452
#         ]
#       },
#       "id": "us6000riuj"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.2,
#         "place": "83 km WNW of Kirakira, Solomon Islands",
#         "time": 1761196838170,
#         "updated": 1761198621599,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000ritz",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000ritz&format=geojson",
#         "felt": 2,
#         "cdi": 3.4,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 417,
#         "net": "us",
#         "code": "6000ritz",
#         "ids": ",us6000ritz,",
#         "sources": ",us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": 66,
#         "dmin": 1.478,
#         "rms": 0.34,
#         "gap": 96,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.2 - 83 km WNW of Kirakira, Solomon Islands"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           161.1807,
#           -10.2846,
#           59.841
#         ]
#       },
#       "id": "us6000ritz"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.2,
#         "place": "49 km ESE of Finschhafen, Papua New Guinea",
#         "time": 1761192421690,
#         "updated": 1761196279359,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rit3",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rit3&format=geojson",
#         "felt": 2,
#         "cdi": 2.1,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 416,
#         "net": "us",
#         "code": "6000rit3",
#         "ids": ",us6000rit3,",
#         "sources": ",us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": 35,
#         "dmin": 2.951,
#         "rms": 0.74,
#         "gap": 89,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.2 - 49 km ESE of Finschhafen, Papua New Guinea"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           148.2843,
#           -6.6541,
#           63.146
#         ]
#       },
#       "id": "us6000rit3"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.6,
#         "place": "191 km SSE of Vilyuchinsk, Russia",
#         "time": 1761186687563,
#         "updated": 1761274521233,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000risn",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000risn&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 3.525,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 482,
#         "net": "us",
#         "code": "6000risn",
#         "ids": ",usauto6000risn,pt25296000,us6000risn,",
#         "sources": ",usauto,pt,us,",
#         "types": ",internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 83,
#         "dmin": 1.748,
#         "rms": 1.01,
#         "gap": 123,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.6 - 191 km SSE of Vilyuchinsk, Russia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           159.653,
#           51.3902,
#           10
#         ]
#       },
#       "id": "us6000risn"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.2,
#         "place": "41 km SSW of Nemuro, Japan",
#         "time": 1761124654054,
#         "updated": 1761325360500,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rimi",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rimi&format=geojson",
#         "felt": 1,
#         "cdi": 3.4,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 416,
#         "net": "us",
#         "code": "6000rimi",
#         "ids": ",us6000rimi,",
#         "sources": ",us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": 117,
#         "dmin": 1.906,
#         "rms": 0.6,
#         "gap": 121,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.2 - 41 km SSW of Nemuro, Japan"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           145.3807,
#           42.9801,
#           59.226
#         ]
#       },
#       "id": "us6000rimi"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "212 km W of Ambon, Indonesia",
#         "time": 1761124033826,
#         "updated": 1761125015040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rimh",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rimh&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rimh",
#         "ids": ",us6000rimh,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 45,
#         "dmin": 3.636,
#         "rms": 0.85,
#         "gap": 46,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - 212 km W of Ambon, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           126.2954,
#           -3.9981,
#           10
#         ]
#       },
#       "id": "us6000rimh"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.9,
#         "place": "7 km SSW of Quepos, Costa Rica",
#         "time": 1761105427885,
#         "updated": 1761269204068,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000ril5",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000ril5&format=geojson",
#         "felt": 215,
#         "cdi": 5.3,
#         "mmi": 5.237,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 649,
#         "net": "us",
#         "code": "6000ril5",
#         "ids": ",us6000ril5,usauto6000ril5,pt25295000,at00t4iln6,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 79,
#         "dmin": 0.411,
#         "rms": 1.34,
#         "gap": 123,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.9 - 7 km SSW of Quepos, Costa Rica"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -84.1795,
#           9.3653,
#           31.021
#         ]
#       },
#       "id": "us6000ril5"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.5,
#         "place": "16 km WNW of Pi\u00f1as, Ecuador",
#         "time": 1761091544149,
#         "updated": 1761316260040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rik7",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rik7&format=geojson",
#         "felt": 26,
#         "cdi": 4.6,
#         "mmi": 4.892,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 477,
#         "net": "us",
#         "code": "6000rik7",
#         "ids": ",us6000rik7,usauto6000rik7,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 108,
#         "dmin": 1.275,
#         "rms": 0.69,
#         "gap": 24,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.5 - 16 km WNW of Pi\u00f1as, Ecuador"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -79.813,
#           -3.6213,
#           73.563
#         ]
#       },
#       "id": "us6000rik7"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "54 km SE of Vilyuchinsk, Russia",
#         "time": 1761089829134,
#         "updated": 1761097492040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rik5",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rik5&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000rik5",
#         "ids": ",usauto6000rik5,us6000rik5,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,origin,phase-data,",
#         "nst": 105,
#         "dmin": 0.478,
#         "rms": 0.69,
#         "gap": 92,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.1 - 54 km SE of Vilyuchinsk, Russia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           159.0021,
#           52.5962,
#           73.819
#         ]
#       },
#       "id": "us6000rik5"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "south of the Kermadec Islands",
#         "time": 1761076924835,
#         "updated": 1761078156040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000riiz",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000riiz&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000riiz",
#         "ids": ",usauto6000riiz,us6000riiz,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,origin,phase-data,",
#         "nst": 33,
#         "dmin": 4.561,
#         "rms": 0.95,
#         "gap": 68,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.1 - south of the Kermadec Islands"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -178.5716,
#           -33.7661,
#           10
#         ]
#       },
#       "id": "us6000riiz"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "34 km W of Ashk\u0101sham, Afghanistan",
#         "time": 1761070489608,
#         "updated": 1761137032040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000riia",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000riia&format=geojson",
#         "felt": 4,
#         "cdi": 2.5,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 401,
#         "net": "us",
#         "code": "6000riia",
#         "ids": ",us6000riia,usauto6000riia,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,moment-tensor,origin,phase-data,",
#         "nst": 125,
#         "dmin": 1.989,
#         "rms": 0.85,
#         "gap": 35,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.1 - 34 km W of Ashk\u0101sham, Afghanistan"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           71.1525,
#           36.6271,
#           243.95
#         ]
#       },
#       "id": "us6000riia"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.2,
#         "place": "South Sandwich Islands region",
#         "time": 1761070268206,
#         "updated": 1761071358040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rii9",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rii9&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 416,
#         "net": "us",
#         "code": "6000rii9",
#         "ids": ",us6000rii9,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 51,
#         "dmin": 7.579,
#         "rms": 0.65,
#         "gap": 86,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.2 - South Sandwich Islands region"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -25.7015,
#           -58.9775,
#           79.271
#         ]
#       },
#       "id": "us6000rii9"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "47 km ENE of N\u016br\u0101b\u0101d, Iran",
#         "time": 1761033756663,
#         "updated": 1761039547241,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rieu",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rieu&format=geojson",
#         "felt": 2,
#         "cdi": 3.5,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rieu",
#         "ids": ",us6000rieu,",
#         "sources": ",us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": 69,
#         "dmin": 6.449,
#         "rms": 1.1,
#         "gap": 90,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - 47 km ENE of N\u016br\u0101b\u0101d, Iran"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           52.0003,
#           30.2273,
#           10
#         ]
#       },
#       "id": "us6000rieu"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "116 km S of Kokopo, Papua New Guinea",
#         "time": 1761018447270,
#         "updated": 1761019636040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rie8",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rie8&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rie8",
#         "ids": ",us6000rie8,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 43,
#         "dmin": 1.21,
#         "rms": 0.69,
#         "gap": 151,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - 116 km S of Kokopo, Papua New Guinea"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           152.397,
#           -5.3863,
#           41.98
#         ]
#       },
#       "id": "us6000rie8"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "Kuril Islands",
#         "time": 1760999429996,
#         "updated": 1761003018040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rid2",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rid2&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000rid2",
#         "ids": ",us6000rid2,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 47,
#         "dmin": 7.518,
#         "rms": 0.69,
#         "gap": 126,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - Kuril Islands"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           153.1502,
#           46.1988,
#           10
#         ]
#       },
#       "id": "us6000rid2"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "13 km N of Esteban\u00eda, Dominican Republic",
#         "time": 1760987626014,
#         "updated": 1761112999270,
# ...
#           151.4646,
#           45.4798,
#           38.589
#         ]
#       },
#       "id": "us6000rehx"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "114 km S of Sungai Penuh, Indonesia",
#         "time": 1759489399368,
#         "updated": 1761660225040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000reh2",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000reh2&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000reh2",
#         "ids": ",us6000reh2,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 111,
#         "dmin": 2.111,
#         "rms": 0.8,
#         "gap": 107,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.1 - 114 km S of Sungai Penuh, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           101.266,
#           -3.0811,
#           61.92
#         ]
#       },
#       "id": "us6000reh2"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.3,
#         "place": "155 km SE of Petropavlovsk-Kamchatsky, Russia",
#         "time": 1759472198083,
#         "updated": 1761370940040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000refw",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000refw&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 432,
#         "net": "us",
#         "code": "6000refw",
#         "ids": ",usauto6000refw,us6000refw,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,moment-tensor,origin,phase-data,",
#         "nst": 78,
#         "dmin": 1.357,
#         "rms": 0.87,
#         "gap": 122,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.3 - 155 km SE of Petropavlovsk-Kamchatsky, Russia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           160.2479,
#           52.0812,
#           16.495
#         ]
#       },
#       "id": "us6000refw"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "92 km ENE of Nabire, Indonesia",
#         "time": 1759471358284,
#         "updated": 1761369780040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000reft",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000reft&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000reft",
#         "ids": ",usauto6000reft,us6000reft,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,origin,phase-data,",
#         "nst": 47,
#         "dmin": 1.765,
#         "rms": 0.95,
#         "gap": 58,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.1 - 92 km ENE of Nabire, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           136.2627,
#           -3.033,
#           10
#         ]
#       },
#       "id": "us6000reft"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "northern Mid-Atlantic Ridge",
#         "time": 1759465071706,
#         "updated": 1761351141040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000reep",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000reep&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 400,
#         "net": "us",
#         "code": "6000reep",
#         "ids": ",usauto6000reep,us6000reep,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,origin,phase-data,",
#         "nst": 100,
#         "dmin": 17.98,
#         "rms": 0.74,
#         "gap": 55,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.1 - northern Mid-Atlantic Ridge"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -43.7754,
#           28.2537,
#           10
#         ]
#       },
#       "id": "us6000reep"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.2,
#         "place": "298 km S of \u2018Ohonua, Tonga",
#         "time": 1759459437455,
#         "updated": 1761344861040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000ree9",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000ree9&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 416,
#         "net": "us",
#         "code": "6000ree9",
#         "ids": ",us6000ree9,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 78,
#         "dmin": 6.971,
#         "rms": 0.94,
#         "gap": 59,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.2 - 298 km S of \u2018Ohonua, Tonga"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -175.2311,
#           -24.0238,
#           10
#         ]
#       },
#       "id": "us6000ree9"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.3,
#         "place": "95 km ENE of Nabire, Indonesia",
#         "time": 1759445105092,
#         "updated": 1761542370040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000redb",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000redb&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 432,
#         "net": "us",
#         "code": "6000redb",
#         "ids": ",usauto6000redb,us6000redb,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,origin,phase-data,",
#         "nst": 64,
#         "dmin": 1.835,
#         "rms": 0.69,
#         "gap": 31,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.3 - 95 km ENE of Nabire, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           136.3208,
#           -3.1055,
#           10
#         ]
#       },
#       "id": "us6000redb"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.3,
#         "place": "16 km WSW of Palompon, Philippines",
#         "time": 1759441195817,
#         "updated": 1761536226682,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000red2",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000red2&format=geojson",
#         "felt": 7,
#         "cdi": 3.4,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 435,
#         "net": "us",
#         "code": "6000red2",
#         "ids": ",us6000red2,usauto6000red2,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,origin,phase-data,",
#         "nst": 65,
#         "dmin": 4.126,
#         "rms": 0.85,
#         "gap": 52,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.3 - 16 km WSW of Palompon, Philippines"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           124.2384,
#           11.0024,
#           10
#         ]
#       },
#       "id": "us6000red2"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.7,
#         "place": "15 km WSW of El Hoyo, Argentina",
#         "time": 1759441077993,
#         "updated": 1761532343931,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000recz",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000recz&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 2.016,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 500,
#         "net": "us",
#         "code": "6000recz",
#         "ids": ",usauto6000recz,us6000recz,",
#         "sources": ",usauto,us,",
#         "types": ",internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 102,
#         "dmin": 5.324,
#         "rms": 0.62,
#         "gap": 33,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.7 - 15 km WSW of El Hoyo, Argentina"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -63.3875,
#           -27.0643,
#           559.2
#         ]
#       },
#       "id": "us6000recz"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "79 km NE of Ardest\u0101n, Iran",
#         "time": 1759437304606,
#         "updated": 1761497411059,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000recq",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000recq&format=geojson",
#         "felt": 37,
#         "cdi": 4.1,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 415,
#         "net": "us",
#         "code": "6000recq",
#         "ids": ",us6000recq,usauto6000recq,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,origin,phase-data,",
#         "nst": 110,
#         "dmin": 6.011,
#         "rms": 0.59,
#         "gap": 47,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.1 - 79 km NE of Ardest\u0101n, Iran"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           52.9734,
#           33.8867,
#           10
#         ]
#       },
#       "id": "us6000recq"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "48 km ESE of Port-Olry, Vanuatu",
#         "time": 1759413632115,
#         "updated": 1761585337040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000re6q",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000re6q&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 385,
#         "net": "us",
#         "code": "6000re6q",
#         "ids": ",us6000re6q,",
#         "sources": ",us,",
#         "types": ",origin,phase-data,",
#         "nst": 74,
#         "dmin": 6.134,
#         "rms": 0.79,
#         "gap": 56,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 5.0 - 48 km ESE of Port-Olry, Vanuatu"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           167.4934,
#           -15.2005,
#           156.967
#         ]
#       },
#       "id": "us6000re6q"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5,
#         "place": "19 km S of Marmara Ere\u011flisi, Turkey",
#         "time": 1759406104173,
#         "updated": 1759916322366,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000re6a",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000re6a&format=geojson",
#         "felt": 102,
#         "cdi": 4.6,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 432,
#         "net": "us",
#         "code": "6000re6a",
#         "ids": ",us6000re6a,usauto6000re6a,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,origin,phase-data,",
#         "nst": 71,
#         "dmin": 1.009,
#         "rms": 1.13,
#         "gap": 36,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.0 - 19 km S of Marmara Ere\u011flisi, Turkey"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           27.9917,
#           40.7968,
#           10
#         ]
#       },
#       "id": "us6000re6a"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.4,
#         "place": "62 km W of Ovalle, Chile",
#         "time": 1759401835573,
#         "updated": 1759489859031,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000re62",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000re62&format=geojson",
#         "felt": 7,
#         "cdi": 3.4,
#         "mmi": 4.851,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 451,
#         "net": "us",
#         "code": "6000re62",
#         "ids": ",us6000re62,usauto6000re62,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 81,
#         "dmin": 0.187,
#         "rms": 1.27,
#         "gap": 84,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.4 - 62 km W of Ovalle, Chile"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -71.8514,
#           -30.6637,
#           19.467
#         ]
#       },
#       "id": "us6000re62"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.1,
#         "place": "16 km ENE of Borbon, Philippines",
#         "time": 1759330018630,
#         "updated": 1759338043216,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000re08",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000re08&format=geojson",
#         "felt": 9,
#         "cdi": 3.4,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 403,
#         "net": "us",
#         "code": "6000re08",
#         "ids": ",us6000re08,usauto6000re08,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,origin,phase-data,",
#         "nst": 89,
#         "dmin": 4.044,
#         "rms": 1.08,
#         "gap": 32,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.1 - 16 km ENE of Borbon, Philippines"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           124.1712,
#           10.8915,
#           10
#         ]
#       },
#       "id": "us6000re08"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 5.6,
#         "place": "197 km NE of Lospalos, Timor Leste",
#         "time": 1759326589991,
#         "updated": 1759414567653,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rdz7",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rdz7&format=geojson",
#         "felt": 1,
#         "cdi": 1,
#         "mmi": 3.403,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 483,
#         "net": "us",
#         "code": "6000rdz7",
#         "ids": ",us6000rdz7,usauto6000rdz7,",
#         "sources": ",us,usauto,",
#         "types": ",dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": 109,
#         "dmin": 4.69,
#         "rms": 0.8,
#         "gap": 18,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 5.6 - 197 km NE of Lospalos, Timor Leste"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           128.3474,
#           -7.349,
#           151.4
#         ]
#       },
#       "id": "us6000rdz7"
#     }
#   ],
#   "bbox": [
#     -179.4701,
#     -60.2617,
#     7.747,
#     178.8255,
#     71.6368,
#     573.03
#   ]
# }

# %%
import requests
import json
from datetime import datetime
# https://www.mapsofworld.com/usa/states/alaska/lat-long.html
response = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-10-01&endtime=2025-10-31&latitude=61&longitude=-150&maxradius=15")
json_response = response.json()
formatted_json = json.dumps(json_response, sort_keys=False, indent=2)

print(formatted_json)
# Out:
# {
#   "type": "FeatureCollection",
#   "metadata": {
#     "generated": 1761681225000,
#     "url": "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-10-01&endtime=2025-10-31&latitude=61&longitude=-150&maxradius=15",
#     "title": "USGS Earthquakes",
#     "status": 200,
#     "api": "1.14.1",
#     "count": 1671
#   },
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.6,
#         "place": "25 km WNW of Clam Gulch, Alaska",
#         "time": 1761679012708,
#         "updated": 1761679133579,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du468nq",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du468nq&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 39,
#         "net": "ak",
#         "code": "025du468nq",
#         "ids": ",ak025du468nq,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.36,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.6 - 25 km WNW of Clam Gulch, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.8241,
#           60.3155,
#           63.9
#         ]
#       },
#       "id": "ak025du468nq"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.9,
#         "place": "51 km S of Denali National Park, Alaska",
#         "time": 1761676674904,
#         "updated": 1761676787813,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du3pb9e",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du3pb9e&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 56,
#         "net": "ak",
#         "code": "025du3pb9e",
#         "ids": ",ak025du3pb9e,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.63,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.9 - 51 km S of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.5231,
#           63.0879,
#           0
#         ]
#       },
#       "id": "ak025du3pb9e"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.3,
#         "place": "24 km NNE of Larsen Bay, Alaska",
#         "time": 1761676084315,
#         "updated": 1761676364585,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du3n9vp",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du3n9vp&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 81,
#         "net": "ak",
#         "code": "025du3n9vp",
#         "ids": ",ak025du3n9vp,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.61,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.3 - 24 km NNE of Larsen Bay, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -153.8984,
#           57.7545,
#           35.1
#         ]
#       },
#       "id": "ak025du3n9vp"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.1,
#         "place": "43 km WSW of Anchor Point, Alaska",
#         "time": 1761674201159,
#         "updated": 1761680179040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du37x7g",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du37x7g&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 68,
#         "net": "ak",
#         "code": "025du37x7g",
#         "ids": ",us6000rk0u,ak025du37x7g,",
#         "sources": ",us,ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.48,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.1 - 43 km WSW of Anchor Point, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -152.5858,
#           59.6965,
#           90.2
#         ]
#       },
#       "id": "ak025du37x7g"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.4,
#         "place": "58 km NE of Denali National Park, Alaska",
#         "time": 1761674157335,
#         "updated": 1761674290748,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du37qu0",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du37qu0&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 30,
#         "net": "ak",
#         "code": "025du37qu0",
#         "ids": ",ak025du37qu0,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.82,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.4 - 58 km NE of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.9065,
#           63.926,
#           65.6
#         ]
#       },
#       "id": "ak025du37qu0"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.6,
#         "place": "54 km E of Denali National Park, Alaska",
#         "time": 1761674107565,
#         "updated": 1761674265890,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du37mzc",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du37mzc&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 39,
#         "net": "ak",
#         "code": "025du37mzc",
#         "ids": ",ak025du37mzc,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.69,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.6 - 54 km E of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.6228,
#           63.5658,
#           6
#         ]
#       },
#       "id": "ak025du37mzc"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.7,
#         "place": "53 km E of Denali National Park, Alaska",
#         "time": 1761673896437,
#         "updated": 1761674001286,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du36u97",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du36u97&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 44,
#         "net": "ak",
#         "code": "025du36u97",
#         "ids": ",ak025du36u97,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.61,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.7 - 53 km E of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.6467,
#           63.5831,
#           0
#         ]
#       },
#       "id": "ak025du36u97"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 3,
#         "place": "44 km SE of Denali National Park, Alaska",
#         "time": 1761671701612,
#         "updated": 1761679102040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du2z1qg",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du2z1qg&format=geojson",
#         "felt": 1,
#         "cdi": 2.7,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 139,
#         "net": "ak",
#         "code": "025du2z1qg",
#         "ids": ",ak025du2z1qg,us6000rk0m,",
#         "sources": ",ak,us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 1.16,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 3.0 - 44 km SE of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.0773,
#           63.2645,
#           0
#         ]
#       },
#       "id": "ak025du2z1qg"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "43 km W of Salamatof, Alaska",
#         "time": 1761664866685,
#         "updated": 1761664984307,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du1th9o",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du1th9o&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025du1th9o",
#         "ids": ",ak025du1th9o,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.27,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 43 km W of Salamatof, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -152.1079,
#           60.6814,
#           79
#         ]
#       },
#       "id": "ak025du1th9o"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.8,
#         "place": "15 km ENE of Willow, Alaska",
#         "time": 1761660559222,
#         "updated": 1761660694156,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du15i1e",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du15i1e&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 50,
#         "net": "ak",
#         "code": "025du15i1e",
#         "ids": ",ak025du15i1e,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.45,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.8 - 15 km ENE of Willow, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -149.7862,
#           61.8202,
#           23.7
#         ]
#       },
#       "id": "ak025du15i1e"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.9,
#         "place": "54 km W of Karluk, Alaska",
#         "time": 1761658352609,
#         "updated": 1761658481672,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du0p0xo",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du0p0xo&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 56,
#         "net": "ak",
#         "code": "025du0p0xo",
#         "ids": ",ak025du0p0xo,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.35,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.9 - 54 km W of Karluk, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -155.365,
#           57.6262,
#           24.9
#         ]
#       },
#       "id": "ak025du0p0xo"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.3,
#         "place": "57 km SSW of Manley Hot Springs, Alaska",
#         "time": 1761657359338,
#         "updated": 1761657493346,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025du0lftp",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025du0lftp&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 26,
#         "net": "ak",
#         "code": "025du0lftp",
#         "ids": ",ak025du0lftp,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.27,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.3 - 57 km SSW of Manley Hot Springs, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.2758,
#           64.567,
#           3
#         ]
#       },
#       "id": "ak025du0lftp"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "61 km E of Cantwell, Alaska",
#         "time": 1761651295858,
#         "updated": 1761652046770,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtzimya",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtzimya&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025dtzimya",
#         "ids": ",ak025dtzimya,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.83,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 61 km E of Cantwell, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -147.7332,
#           63.4803,
#           0
#         ]
#       },
#       "id": "ak025dtzimya"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.1,
#         "place": "19 km ENE of Minto, Alaska",
#         "time": 1761650398521,
#         "updated": 1761650561623,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtzfff0",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtzfff0&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 19,
#         "net": "ak",
#         "code": "025dtzfff0",
#         "ids": ",ak025dtzfff0,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.88,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.1 - 19 km ENE of Minto, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -148.9987,
#           65.2443,
#           2.9
#         ]
#       },
#       "id": "ak025dtzfff0"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.5,
#         "place": "27 km SE of Denali National Park, Alaska",
#         "time": 1761649667734,
#         "updated": 1761650430198,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtzctu8",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtzctu8&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 96,
#         "net": "ak",
#         "code": "025dtzctu8",
#         "ids": ",ak025dtzctu8,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.89,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.5 - 27 km SE of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.298,
#           63.3807,
#           14.3
#         ]
#       },
#       "id": "ak025dtzctu8"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.6,
#         "place": "8 km SSE of Point MacKenzie, Alaska",
#         "time": 1761649518492,
#         "updated": 1761649634146,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtzccax",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtzccax&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 39,
#         "net": "ak",
#         "code": "025dtzccax",
#         "ids": ",ak025dtzccax,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.74,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.6 - 8 km SSE of Point MacKenzie, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -149.9004,
#           61.2968,
#           35.9
#         ]
#       },
#       "id": "ak025dtzccax"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 0.9,
#         "place": null,
#         "time": 1761646703744,
#         "updated": 1761646804933,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtytpeu",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtytpeu&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 12,
#         "net": "ak",
#         "code": "025dtytpeu",
#         "ids": ",ak025dtytpeu,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.22,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 0.9 - "
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -152.7816,
#           60.3012,
#           113.4
#         ]
#       },
#       "id": "ak025dtytpeu"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 0.9,
#         "place": "15 km NNE of Four Mile Road, Alaska",
#         "time": 1761645316078,
#         "updated": 1761645427603,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtyg6pj",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtyg6pj&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 12,
#         "net": "ak",
#         "code": "025dtyg6pj",
#         "ids": ",ak025dtyg6pj,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.22,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 0.9 - 15 km NNE of Four Mile Road, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -149.0133,
#           64.7312,
#           13.6
#         ]
#       },
#       "id": "ak025dtyg6pj"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.4,
#         "place": "10 km N of Willow, Alaska",
#         "time": 1761641344795,
#         "updated": 1761641435438,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtxtfxr",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtxtfxr&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 30,
#         "net": "ak",
#         "code": "025dtxtfxr",
#         "ids": ",ak025dtxtfxr,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.4,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.4 - 10 km N of Willow, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.0122,
#           61.837,
#           32.4
#         ]
#       },
#       "id": "ak025dtxtfxr"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "39 km ENE of Chase, Alaska",
#         "time": 1761639173812,
#         "updated": 1761639329033,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtxlm18",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtxlm18&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025dtxlm18",
#         "ids": ",ak025dtxlm18,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 1.58,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 39 km ENE of Chase, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -149.3524,
#           62.53,
#           30.2
#         ]
#       },
#       "id": "ak025dtxlm18"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.7,
#         "place": "19 km WNW of Chignik Lake, Alaska",
#         "time": 1761636499965,
#         "updated": 1761636682745,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtx3jgs",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtx3jgs&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 44,
#         "net": "ak",
#         "code": "025dtx3jgs",
#         "ids": ",ak025dtx3jgs,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.39,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.7 - 19 km WNW of Chignik Lake, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -159.0201,
#           56.3495,
#           126.7
#         ]
#       },
#       "id": "ak025dtx3jgs"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "36 km WNW of Nikiski, Alaska",
#         "time": 1761635310541,
#         "updated": 1761635649382,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtwz9u8",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtwz9u8&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025dtwz9u8",
#         "ids": ",ak025dtwz9u8,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.86,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 36 km WNW of Nikiski, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.9496,
#           60.7613,
#           87.3
#         ]
#       },
#       "id": "ak025dtwz9u8"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "27 km NNW of Karluk, Alaska",
#         "time": 1761635072326,
#         "updated": 1761635251222,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtwyf8g",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtwyf8g&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025dtwyf8g",
#         "ids": ",ak025dtwyf8g,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.2,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 27 km NNW of Karluk, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -154.6689,
#           57.7886,
#           50.7
#         ]
#       },
#       "id": "ak025dtwyf8g"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.4,
#         "place": "55 km NW of Ninilchik, Alaska",
#         "time": 1761634315479,
#         "updated": 1761634407784,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtwn42j",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtwn42j&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 30,
#         "net": "ak",
#         "code": "025dtwn42j",
#         "ids": ",ak025dtwn42j,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.21,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.4 - 55 km NW of Ninilchik, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -152.4827,
#           60.3446,
#           105.5
#         ]
#       },
#       "id": "ak025dtwn42j"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.6,
#         "place": "16 km NW of Ninilchik, Alaska",
#         "time": 1761632765600,
#         "updated": 1761633099204,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtwhn93",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtwhn93&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 39,
#         "net": "ak",
#         "code": "025dtwhn93",
#         "ids": ",ak025dtwhn93,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.29,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.6 - 16 km NW of Ninilchik, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.8986,
#           60.143,
#           65
#         ]
#       },
#       "id": "ak025dtwhn93"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.8,
#         "place": "63 km W of Tyonek, Alaska",
#         "time": 1761631750588,
#         "updated": 1761632349539,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtwe0iv",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtwe0iv&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 50,
#         "net": "ak",
#         "code": "025dtwe0iv",
#         "ids": ",ak025dtwe0iv,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.51,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.8 - 63 km W of Tyonek, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -152.3101,
#           61.0275,
#           108.3
#         ]
#       },
#       "id": "ak025dtwe0iv"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.7,
#         "place": "55 km WNW of Skwentna, Alaska",
#         "time": 1761630995219,
#         "updated": 1761631751484,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtw2psm",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtw2psm&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 44,
#         "net": "ak",
#         "code": "025dtw2psm",
#         "ids": ",ak025dtw2psm,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.48,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.7 - 55 km WNW of Skwentna, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -152.3037,
#           62.2519,
#           119.6
#         ]
#       },
#       "id": "ak025dtw2psm"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.7,
#         "place": "22 km E of Pedro Bay, Alaska",
#         "time": 1761628664703,
#         "updated": 1761628806739,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtvudae",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtvudae&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 44,
#         "net": "ak",
#         "code": "025dtvudae",
#         "ids": ",ak025dtvudae,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.48,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.7 - 22 km E of Pedro Bay, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -153.7039,
#           59.7881,
#           128.5
#         ]
#       },
#       "id": "ak025dtvudae"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.6,
#         "place": "47 km SE of Kokhanok, Alaska",
#         "time": 1761627255598,
#         "updated": 1761629598040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtvgsxe",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtvgsxe&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 104,
#         "net": "ak",
#         "code": "025dtvgsxe",
#         "ids": ",us6000rjus,ak025dtvgsxe,",
#         "sources": ",us,ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.59,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.6 - 47 km SE of Kokhanok, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -154.1805,
#           59.1376,
#           125.9
#         ]
#       },
#       "id": "ak025dtvgsxe"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.8,
#         "place": "38 km SE of Denali National Park, Alaska",
#         "time": 1761622553033,
#         "updated": 1761622784139,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dturdii",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dturdii&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 50,
#         "net": "ak",
#         "code": "025dturdii",
#         "ids": ",ak025dturdii,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.98,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.8 - 38 km SE of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.1108,
#           63.3257,
#           0
#         ]
#       },
#       "id": "ak025dturdii"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 0.6,
#         "place": "25 km E of Ugashik, Alaska",
#         "time": 1761622305973,
#         "updated": 1761622625213,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtuqi79",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtuqi79&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 6,
#         "net": "ak",
#         "code": "025dtuqi79",
#         "ids": ",ak025dtuqi79,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.89,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 0.6 - 25 km E of Ugashik, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -156.9827,
#           57.5404,
#           204.6
#         ]
#       },
#       "id": "ak025dtuqi79"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.3,
#         "place": "61 km NW of Beluga, Alaska",
#         "time": 1761621745302,
#         "updated": 1761621852505,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtuoj5u",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtuoj5u&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 26,
#         "net": "ak",
#         "code": "025dtuoj5u",
#         "ids": ",ak025dtuoj5u,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.45,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.3 - 61 km NW of Beluga, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.9723,
#           61.4849,
#           0
#         ]
#       },
#       "id": "ak025dtuoj5u"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 0.6,
#         "place": "68 km WNW of Beluga, Alaska",
#         "time": 1761621150685,
#         "updated": 1761621277682,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtumeg0",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtumeg0&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 6,
#         "net": "ak",
#         "code": "025dtumeg0",
#         "ids": ",ak025dtumeg0,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.17,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 0.6 - 68 km WNW of Beluga, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -152.2947,
#           61.336,
#           7.2
#         ]
#       },
#       "id": "ak025dtumeg0"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.5,
#         "place": "72 km WSW of Karluk, Alaska",
#         "time": 1761619162470,
#         "updated": 1761629280040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtu6qhk",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtu6qhk&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 96,
#         "net": "ak",
#         "code": "025dtu6qhk",
#         "ids": ",us6000rjuh,ak025dtu6qhk,",
#         "sources": ",us,ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.56,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.5 - 72 km WSW of Karluk, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -155.5932,
#           57.3442,
#           34.5
#         ]
#       },
#       "id": "ak025dtu6qhk"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 3.3,
#         "place": "161 km SW of Nikolski, Alaska",
#         "time": 1761616154630,
#         "updated": 1761637551301,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dttnffa",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dttnffa&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 1.633,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 168,
#         "net": "ak",
#         "code": "025dttnffa",
#         "ids": ",ak025dttnffa,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": null,
#         "rms": 1.28,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 3.3 - 161 km SW of Nikolski, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -170.8033,
#           52.1051,
#           25.7
#         ]
#       },
#       "id": "ak025dttnffa"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "57 km S of Denali National Park, Alaska",
#         "time": 1761613013854,
#         "updated": 1761613754974,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dtt3kwc",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dtt3kwc&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025dtt3kwc",
#         "ids": ",ak025dtt3kwc,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.76,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 57 km S of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.5558,
#           63.027,
#           0.1
#         ]
#       },
#       "id": "ak025dtt3kwc"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 4.2,
#         "place": "96 km SSE of Sand Point, Alaska",
#         "time": 1761608748868,
#         "updated": 1761637101558,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000rjty",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rjty&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 2.175,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 271,
#         "net": "us",
#         "code": "6000rjty",
#         "ids": ",ak025dsj6u55,us6000rjty,",
#         "sources": ",ak,us,",
#         "types": ",origin,phase-data,shakemap,",
#         "nst": 29,
#         "dmin": 1.479,
#         "rms": 0.47,
#         "gap": 185,
#         "magType": "mb",
#         "type": "earthquake",
#         "title": "M 4.2 - 96 km SSE of Sand Point, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -160.0841,
#           54.5065,
#           35
#         ]
#       },
#       "id": "us6000rjty"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.9,
#         "place": "16 km W of Petersville, Alaska",
#         "time": 1761607555886,
#         "updated": 1761614447040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dsj2k6b",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dsj2k6b&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 129,
#         "net": "ak",
#         "code": "025dsj2k6b",
#         "ids": ",us6000rjtt,ak025dsj2k6b,",
#         "sources": ",us,ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.61,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.9 - 16 km W of Petersville, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.0904,
#           62.494,
#           82.7
#         ]
#       },
#       "id": "ak025dsj2k6b"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.2,
#         "place": "37 km SSE of Central, Alaska",
#         "time": 1761607033886,
#         "updated": 1761607789595,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dsj0rb0",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dsj0rb0&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 74,
#         "net": "ak",
#         "code": "025dsj0rb0",
#         "ids": ",ak025dsj0rb0,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.65,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.2 - 37 km SSE of Central, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -144.6047,
#           65.2437,
#           0
#         ]
#       },
#       "id": "ak025dsj0rb0"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.6,
#         "place": "20 km WSW of Glacier View, Alaska",
#         "time": 1761606449945,
#         "updated": 1761612198040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dsiynbx",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dsiynbx&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 104,
#         "net": "ak",
#         "code": "025dsiynbx",
#         "ids": ",us6000rjtl,ak025dsiynbx,",
#         "sources": ",us,ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.83,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.6 - 20 km WSW of Glacier View, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -148.0195,
#           61.7462,
#           21.7
#         ]
#       },
#       "id": "ak025dsiynbx"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.1,
#         "place": "52 km NE of Chase, Alaska",
#         "time": 1761606253749,
#         "updated": 1761606349737,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dsixyzi",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dsixyzi&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 19,
#         "net": "ak",
#         "code": "025dsixyzi",
#         "ids": ",ak025dsixyzi,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.38,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.1 - 52 km NE of Chase, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -149.4956,
#           62.8321,
#           74.8
#         ]
#       },
#       "id": "ak025dsixyzi"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.4,
#         "place": "24 km S of Funny River, Alaska",
#         "time": 1761605511151,
#         "updated": 1761605640015,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dsimox7",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dsimox7&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 30,
#         "net": "ak",
#         "code": "025dsimox7",
#         "ids": ",ak025dsimox7,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.45,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.4 - 24 km S of Funny River, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.7919,
#           60.2825,
#           0
#         ]
#       },
#       "id": "ak025dsimox7"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 0.9,
#         "place": "84 km E of Lime Village, Alaska",
#         "time": 1761604752441,
#         "updated": 1761604902549,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dsik1cc",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dsik1cc&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 12,
#         "net": "ak",
#         "code": "025dsik1cc",
#         "ids": ",ak025dsik1cc,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.36,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 0.9 - 84 km E of Lime Village, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -153.8706,
#           61.2669,
#           13.8
#         ]
#       },
#       "id": "ak025dsik1cc"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.3,
#         "place": "28 km NNE of Fishhook, Alaska",
#         "time": 1761604625604,
#         "updated": 1761605380863,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025dsijlds",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025dsijlds&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 26,
#         "net": "ak",
#         "code": "025dsijlds",
#         "ids": ",ak025dsijlds,",
# ...
#         "tsunami": 0,
#         "sig": 30,
#         "net": "ak",
#         "code": "025cl8ex9k",
#         "ids": ",av93799738,ak025cl8ex9k,",
#         "sources": ",av,ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.69,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.4 - 77 km W of Karluk, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -155.7566,
#           57.5859,
#           30.6
#         ]
#       },
#       "id": "ak025cl8ex9k"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.4,
#         "place": "33 km ENE of Susitna North, Alaska",
#         "time": 1759296181470,
#         "updated": 1759296917705,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl8d6wz",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl8d6wz&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 30,
#         "net": "ak",
#         "code": "025cl8d6wz",
#         "ids": ",ak025cl8d6wz,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.36,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.4 - 33 km ENE of Susitna North, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -149.2313,
#           62.2359,
#           19.9
#         ]
#       },
#       "id": "ak025cl8d6wz"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.1,
#         "place": "25 km NE of Chickaloon, Alaska",
#         "time": 1759293581426,
#         "updated": 1759293720374,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl7v9um",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl7v9um&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 19,
#         "net": "ak",
#         "code": "025cl7v9um",
#         "ids": ",ak025cl7v9um,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.56,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.1 - 25 km NE of Chickaloon, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -148.1817,
#           61.9866,
#           39
#         ]
#       },
#       "id": "ak025cl7v9um"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "72 km ESE of Denali National Park, Alaska",
#         "time": 1759293243304,
#         "updated": 1759293396371,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl7u4bu",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl7u4bu&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025cl7u4bu",
#         "ids": ",ak025cl7u4bu,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 1.27,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 72 km ESE of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.3974,
#           63.2722,
#           32
#         ]
#       },
#       "id": "ak025cl7u4bu"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "35 km WNW of Willow, Alaska",
#         "time": 1759292827556,
#         "updated": 1759292945670,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl7smn7",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl7smn7&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025cl7smn7",
#         "ids": ",ak025cl7smn7,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 1.11,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 35 km WNW of Willow, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.6289,
#           61.9067,
#           10.6
#         ]
#       },
#       "id": "ak025cl7smn7"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.7,
#         "place": "79 km NW of Paxson, Alaska",
#         "time": 1759290136847,
#         "updated": 1759290272056,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl7afhw",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl7afhw&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 44,
#         "net": "ak",
#         "code": "025cl7afhw",
#         "ids": ",ak025cl7afhw,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 1.2,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.7 - 79 km NW of Paxson, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -146.8801,
#           63.5164,
#           13.6
#         ]
#       },
#       "id": "ak025cl7afhw"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "10 km ESE of Ninilchik, Alaska",
#         "time": 1759289772172,
#         "updated": 1759289854603,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl794u9",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl794u9&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025cl794u9",
#         "ids": ",ak025cl794u9,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.14,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 10 km ESE of Ninilchik, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.4956,
#           60.01,
#           57.5
#         ]
#       },
#       "id": "ak025cl794u9"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "25 km SW of Tyonek, Alaska",
#         "time": 1759289491432,
#         "updated": 1759289585910,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl783qv",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl783qv&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025cl783qv",
#         "ids": ",ak025cl783qv,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.67,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 25 km SW of Tyonek, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.5086,
#           60.9263,
#           59.3
#         ]
#       },
#       "id": "ak025cl783qv"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": -0.66,
#         "place": "60 km ENE of Pedro Bay, Alaska",
#         "time": 1759285086590,
#         "updated": 1759352531430,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av93799553",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93799553&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 0,
#         "net": "av",
#         "code": "93799553",
#         "ids": ",av93799553,",
#         "sources": ",av,",
#         "types": ",origin,phase-data,",
#         "nst": 5,
#         "dmin": 0.02647,
#         "rms": 0.07,
#         "gap": 123,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M -0.7 - 60 km ENE of Pedro Bay, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -153.107333333333,
#           60.0028333333333,
#           1.34
#         ]
#       },
#       "id": "av93799553"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": -0.1,
#         "place": "85 km NW of Karluk, Alaska",
#         "time": 1759285023630,
#         "updated": 1759352300240,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av93799548",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93799548&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 0,
#         "net": "av",
#         "code": "93799548",
#         "ids": ",av93799548,",
#         "sources": ",av,",
#         "types": ",origin,phase-data,",
#         "nst": 10,
#         "dmin": 0.04182,
#         "rms": 0.1,
#         "gap": 77,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M -0.1 - 85 km NW of Karluk, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -155.355666666667,
#           58.1711666666667,
#           1.7
#         ]
#       },
#       "id": "av93799548"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "33 km N of Petersville, Alaska",
#         "time": 1759282247673,
#         "updated": 1759282359602,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl6122n",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl6122n&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025cl6122n",
#         "ids": ",ak025cl6122n,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.36,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 33 km N of Petersville, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.8239,
#           62.7986,
#           87.3
#         ]
#       },
#       "id": "ak025cl6122n"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.5,
#         "place": "15 km ESE of Clam Gulch, Alaska",
#         "time": 1759281548376,
#         "updated": 1759281656690,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl5ym5x",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl5ym5x&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 35,
#         "net": "ak",
#         "code": "025cl5ym5x",
#         "ids": ",ak025cl5ym5x,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.34,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.5 - 15 km ESE of Clam Gulch, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -151.1417,
#           60.1691,
#           67
#         ]
#       },
#       "id": "ak025cl5ym5x"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.25,
#         "place": "69 km SSW of Ugashik, Alaska",
#         "time": 1759278608810,
#         "updated": 1759351285850,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av93050339",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93050339&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 24,
#         "net": "av",
#         "code": "93050339",
#         "ids": ",av93050339,",
#         "sources": ",av,",
#         "types": ",origin,phase-data,",
#         "nst": 6,
#         "dmin": 0.2253,
#         "rms": 0.15,
#         "gap": 330,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.3 - 69 km SSW of Ugashik, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -157.704666666667,
#           56.9083333333333,
#           3.86
#         ]
#       },
#       "id": "av93050339"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 1.7,
#         "place": "65 km SE of Denali National Park, Alaska",
#         "time": 1759278578403,
#         "updated": 1759279247749,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl5fe3g",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl5fe3g&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 44,
#         "net": "ak",
#         "code": "025cl5fe3g",
#         "ids": ",ak025cl5fe3g,",
#         "sources": ",ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.41,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 1.7 - 65 km SE of Denali National Park, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -150.8038,
#           63.1268,
#           117
#         ]
#       },
#       "id": "ak025cl5fe3g"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 2.5,
#         "place": "44 km S of Ugashik, Alaska",
#         "time": 1759277234322,
#         "updated": 1759278309040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak025cl5amet",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak025cl5amet&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": null,
#         "alert": null,
#         "status": "automatic",
#         "tsunami": 0,
#         "sig": 96,
#         "net": "ak",
#         "code": "025cl5amet",
#         "ids": ",us6000rdxc,ak025cl5amet,",
#         "sources": ",us,ak,",
#         "types": ",origin,phase-data,",
#         "nst": null,
#         "dmin": null,
#         "rms": 0.54,
#         "gap": null,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 2.5 - 44 km S of Ugashik, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -157.4708,
#           57.1111,
#           2.7
#         ]
#       },
#       "id": "ak025cl5amet"
#     }
#   ],
#   "bbox": [
#     -170.8033,
#     52.005,
#     -3.18,
#     -131.8847,
#     71.6368,
#     249.9
#   ]
# }

# %% [markdown]
# # back to the task at hand
# #### Getting what we need...
# Now, we will *print the place, date, and magnitude of each of them*
#
# Here is what we used:
# ```json
# "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.2,
#         "place": "66 km E of Hualien City, Taiwan",
#         "time": 1641203195767,
# ...
# ```

# %%
max_magnitude = 0

for earthquake in json_response["features"]:
    magnitude = earthquake["properties"]["mag"]
    print("----")
    print("Place:  " + earthquake["properties"]["place"])
    print("Time:  " + str(earthquake["properties"]["time"]))
    print("Mag:  " + str(magnitude))
    if (magnitude > max_magnitude):
        max_magnitude = magnitude
print ("\nMaximum magnitude: " + str(max_magnitude))
# Out:
# ----
# Place:  Kermadec Islands region
# Time:  1643424399588
# Mag:  6.5
# ----
# Place:  281 km SW of Arenas, Panama
# Time:  1643368449293
# Mag:  6
# ----
# Place:  220 km WNW of Pangai, Tonga
# Time:  1643265605543
# Mag:  6.2
# ----
# Place:  South Sandwich Islands region
# Time:  1643073873513
# Mag:  6
# ----
# Place:  71 km S of Unalaska, Alaska
# Time:  1642828624896
# Mag:  6.2
# ----
# Place:  232 km SE of Sarangani, Philippines
# Time:  1642818373323
# Mag:  6
# ----
# Place:  27 km SSE of Saiki, Japan
# Time:  1642781317210
# Mag:  6.3
# ----
# Place:  74 km WSW of Panguna, Papua New Guinea
# Time:  1642337528025
# Mag:  6.1
# ----
# Place:  80 km SW of Labuan, Indonesia
# Time:  1642151141461
# Mag:  6.6
# ----
# Place:  53 km SE of Nikolski, Alaska
# Time:  1641904772454
# Mag:  6.6
# ----
# Place:  100 km SE of Nikolski, Alaska
# Time:  1641900943674
# Mag:  6.8
# ----
# Place:  48 km WNW of Pólis, Cyprus
# Time:  1641863268064
# Mag:  6.6
# ----
# Place:  south of the Kermadec Islands
# Time:  1641773190834
# Mag:  6.2
# ----
# Place:  northern Qinghai, China
# Time:  1641577530809
# Mag:  6.6
# ----
# Place:  near the coast of Nicaragua
# Time:  1641486305973
# Mag:  6.1
# ----
# Place:  284 km E of Katabu, Indonesia
# Time:  1641329746858
# Mag:  6
# ----
# Place:  66 km E of Hualien City, Taiwan
# Time:  1641203195767
# Mag:  6.2
# ----
# Place:  110 km NW of Sola, Vanuatu
# Time:  1641175784647
# Mag:  6
#
# Maximum magnitude: 6.8
